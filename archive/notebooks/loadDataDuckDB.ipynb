# %%
#%pip install duckdb leafmap
#%pip install "xarray[io]"
#%pip install jupysql
#%pip install duckdb-engine --quiet # To use DuckDB with JupyterSQL for %%sql commands

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import duckdb
import leafmap
import pandas as pd
import xarray as xr


# Import jupysql Jupyter extension to create SQL cells
# %load_ext sql

# configurations on jupysql to directly output data to Pandas and to simplify the output
# %config SqlMagic.autopandas = True
# %config SqlMagic.feedback = False
# %config SqlMagic.displaycon = False

# %%
def read_csv_file(file_path):
    df = pd.read_csv(file_path)
    # print(df.head())
    # print(df.tail())
    # print(df.columns)
    # print(df.shape)
    # print(df.info())
    return df

def get_column_values(df, column_name):
    if column_name in df.columns:
        return df[column_name].tolist()
    else:
        raise ValueError(f"Column '{column_name}' does not exist in the DataFrame")

def process_raster_names(raster_names):
    processed_names = []
    for name in raster_names:
        if ":" in name:
            extracted_name = name.split(":", 1)[1].strip().lower().replace(" ", "_")
            processed_names.append(extracted_name)
    return processed_names

def extract_data_points_vectorized_long_lat(ds, raster_column_values_lowercased):
    # Convert the dataset to a pandas DataFrame
    df = (
        ds.to_dataframe().reset_index()
    )  # .reset_index() is used to convert the index to columns

    # print("---Before reshaping---")
    # print(df.head())
    # print(df.tail())
    # print(df.columns)
    # print(df.shape)
    # print(df.info())

    # Assuming 'df' is your original DataFrame with the columns shown
    df.columns = [
        "raster",
        "latitude",
        "longitude",
        "Basic Demographic Characteristics, v4.10 (2010): Male, Density, 2.5 arc-minutes", #TODO: More generic
    ]

    # Use pivot for vectorized reshaping
    reshaped_df = df.pivot(
        index=["latitude", "longitude"],
        columns="raster",
        values="Basic Demographic Characteristics, v4.10 (2010): Male, Density, 2.5 arc-minutes", #TODO: More generic
    )

    # Reset the index to turn 'latitude' and 'longitude' back into columns
    reshaped_df.reset_index(inplace=True)

    # Rename the raster columns to have a prefix
    reshaped_df.columns = ["latitude", "longitude"] + [
        raster_column_values_lowercased[int(col) - 1] if not pd.isnull(col) else col
        for col in reshaped_df.columns[2:]
    ]

    # print("---After reshaping---")
    # print(reshaped_df.head())
    # print(reshaped_df.tail())
    # print(reshaped_df.columns)
    # print(reshaped_df.shape)
    # print(reshaped_df.info())

    return reshaped_df

def load_dataset(file_path, lat_slice, lon_slice):
    dataset = xr.open_dataset(file_path)
    # TODO: Fix out of memory problem by using dask https://tutorial.xarray.dev/intermediate/xarray_and_dask.html
    data_slice = dataset.sel(latitude=lat_slice, longitude=lon_slice)
    data_slice = data_slice[
        "Basic Demographic Characteristics, v4.10 (2010): Male, Density, 2.5 arc-minutes" #TODO: Make this dynamic
    ]
    return data_slice.compute()

# %% [markdown]
# ### Paths for data and additional files from original dataset to do lookups/renamings

# %%
file_path_male = "../data/gpw_v4_basic_demographic_characteristics_rev11_mt_2010_dens_2pt5_min.nc"
file_path_male_raster_lookup = "../data/gpw_v4_basic_demographic_characteristics_rev11_mt_2010_dens_2pt5_min_lookup.csv"
df_file_path_male_raster_lookup = read_csv_file(file_path_male_raster_lookup)
raster_column_values = get_column_values(
    df_file_path_male_raster_lookup, "raster_name"
)

raster_column_values_lowercased = process_raster_names(raster_column_values)

print(raster_column_values_lowercased)
# Out:
# ['male_population_density', 'male_population_density_ages_0_to_4', 'male_population_density_ages_5_to_9', 'male_population_density_ages_10_to_14', 'male_population_density_ages_15_to_19', 'male_population_density_ages_20_to_24', 'male_population_density_ages_25_to_29', 'male_population_density_ages_30_to_34', 'male_population_density_ages_35_to_39', 'male_population_density_ages_40_to_44', 'male_population_density_ages_45_to_49', 'male_population_density_ages_50_to_54', 'male_population_density_ages_55_to_59', 'male_population_density_ages_60_to_64', 'male_population_density_ages_65_and_over', 'data_context', 'mean_administrative_unit_area', 'water_mask', 'land_area', 'water_area', 'national_identifier_grid', 'data_code', 'input_data_year', 'input_data_level', 'input_sex_data_level', 'input_age_data_level', 'growth_rate_start_year', 'growth_rate_end_year', 'growth_rate_administrative_level', 'year_of_most_recent_census']

# %% [markdown]
# ### Actual loading of data

# %%
lat_slice = slice(85, -85)  # Dosen't work with value over 85 or under -85
lon_slice = slice(6, 7)

data_slice_male = load_dataset(file_path_male, lat_slice, lon_slice)
data_slice_male_long_lat = extract_data_points_vectorized_long_lat(data_slice_male, raster_column_values_lowercased)

data_slice_male_long_lat
# Out:
#         latitude  longitude  male_population_density  \
# 0     -84.979167   6.020833                      NaN
# 1     -84.979167   6.062500                      NaN
# 2     -84.979167   6.104167                      NaN
# 3     -84.979167   6.145833                      NaN
# 4     -84.979167   6.187500                      NaN
# ...          ...        ...                      ...
# 97915  84.979167   6.812500                      NaN
# 97916  84.979167   6.854167                      NaN
# 97917  84.979167   6.895833                      NaN
# 97918  84.979167   6.937500                      NaN
# 97919  84.979167   6.979167                      NaN
#
#        male_population_density_ages_0_to_4  \
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# 3                                      NaN
# 4                                      NaN
# ...                                    ...
# 97915                                  NaN
# 97916                                  NaN
# 97917                                  NaN
# 97918                                  NaN
# 97919                                  NaN
#
#        male_population_density_ages_5_to_9  \
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# 3                                      NaN
# 4                                      NaN
# ...                                    ...
# 97915                                  NaN
# 97916                                  NaN
# 97917                                  NaN
# 97918                                  NaN
# 97919                                  NaN
#
#        male_population_density_ages_10_to_14  \
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4                                        NaN
# ...                                      ...
# 97915                                    NaN
# 97916                                    NaN
# 97917                                    NaN
# 97918                                    NaN
# 97919                                    NaN
#
#        male_population_density_ages_15_to_19  \
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4                                        NaN
# ...                                      ...
# 97915                                    NaN
# 97916                                    NaN
# 97917                                    NaN
# 97918                                    NaN
# 97919                                    NaN
#
#        male_population_density_ages_20_to_24  \
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4                                        NaN
# ...                                      ...
# 97915                                    NaN
# 97916                                    NaN
# 97917                                    NaN
# 97918                                    NaN
# 97919                                    NaN
#
#        male_population_density_ages_25_to_29  \
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4                                        NaN
# ...                                      ...
# 97915                                    NaN
# 97916                                    NaN
# 97917                                    NaN
# 97918                                    NaN
# 97919                                    NaN
#
#        male_population_density_ages_30_to_34  ...  national_identifier_grid  \
# 0                                        NaN  ...                   32767.0
# 1                                        NaN  ...                   32767.0
# 2                                        NaN  ...                   32767.0
# 3                                        NaN  ...                   32767.0
# 4                                        NaN  ...                   32767.0
# ...                                      ...  ...                       ...
# 97915                                    NaN  ...                   32767.0
# 97916                                    NaN  ...                   32767.0
# 97917                                    NaN  ...                   32767.0
# 97918                                    NaN  ...                   32767.0
# 97919                                    NaN  ...                   32767.0
#
#        data_code  input_data_year  input_data_level  input_sex_data_level  \
# 0            NaN              NaN               NaN                   NaN
# 1            NaN              NaN               NaN                   NaN
# 2            NaN              NaN               NaN                   NaN
# 3            NaN              NaN               NaN                   NaN
# 4            NaN              NaN               NaN                   NaN
# ...          ...              ...               ...                   ...
# 97915        NaN              NaN               NaN                   NaN
# 97916        NaN              NaN               NaN                   NaN
# 97917        NaN              NaN               NaN                   NaN
# 97918        NaN              NaN               NaN                   NaN
# 97919        NaN              NaN               NaN                   NaN
#
#        input_age_data_level  growth_rate_start_year  growth_rate_end_year  \
# 0                       NaN                     NaN                   NaN
# 1                       NaN                     NaN                   NaN
# 2                       NaN                     NaN                   NaN
# 3                       NaN                     NaN                   NaN
# 4                       NaN                     NaN                   NaN
# ...                     ...                     ...                   ...
# 97915                   NaN                     NaN                   NaN
# 97916                   NaN                     NaN                   NaN
# 97917                   NaN                     NaN                   NaN
# 97918                   NaN                     NaN                   NaN
# 97919                   NaN                     NaN                   NaN
#
#        growth_rate_administrative_level  year_of_most_recent_census
# 0                                   NaN                         NaN
# 1                                   NaN                         NaN
# 2                                   NaN                         NaN
# 3                                   NaN                         NaN
# 4                                   NaN                         NaN
# ...                                 ...                         ...
# 97915                               NaN                         NaN
# 97916                               NaN                         NaN
# 97917                               NaN                         NaN
# 97918                               NaN                         NaN
# 97919                               NaN                         NaN
#
# [97920 rows x 32 columns]

# %%
data_slice_male_long_lat.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 97920 entries, 0 to 97919
# Data columns (total 32 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   latitude                                  97920 non-null  float64
#  1   longitude                                 97920 non-null  float64
#  2   male_population_density                   27512 non-null  float32
#  3   male_population_density_ages_0_to_4       27512 non-null  float32
#  4   male_population_density_ages_5_to_9       27512 non-null  float32
#  5   male_population_density_ages_10_to_14     27512 non-null  float32
#  6   male_population_density_ages_15_to_19     27512 non-null  float32
#  7   male_population_density_ages_20_to_24     27512 non-null  float32
#  8   male_population_density_ages_25_to_29     27512 non-null  float32
#  9   male_population_density_ages_30_to_34     27512 non-null  float32
#  10  male_population_density_ages_35_to_39     27512 non-null  float32
#  11  male_population_density_ages_40_to_44     27512 non-null  float32
#  12  male_population_density_ages_45_to_49     27512 non-null  float32
#  13  male_population_density_ages_50_to_54     27512 non-null  float32
#  14  male_population_density_ages_55_to_59     27512 non-null  float32
#  15  male_population_density_ages_60_to_64     27512 non-null  float32
#  16  male_population_density_ages_65_and_over  27512 non-null  float32
#  17  data_context                              27512 non-null  float32
#  18  mean_administrative_unit_area             27512 non-null  float32
#  19  water_mask                                97920 non-null  float32
#  20  land_area                                 27512 non-null  float32
#  21  water_area                                27560 non-null  float32
#  22  national_identifier_grid                  97920 non-null  float32
#  23  data_code                                 27512 non-null  float32
#  24  input_data_year                           27512 non-null  float32
#  25  input_data_level                          27512 non-null  float32
#  26  input_sex_data_level                      27512 non-null  float32
#  27  input_age_data_level                      27512 non-null  float32
#  28  growth_rate_start_year                    27512 non-null  float32
#  29  growth_rate_end_year                      27512 non-null  float32
#  30  growth_rate_administrative_level          27512 non-null  float32
#  31  year_of_most_recent_census                27512 non-null  float32
# dtypes: float32(30), float64(2)
# memory usage: 12.7 MB

# %%
con = duckdb.connect() # Note: duckdb.sql connects to the default in-memory database connection
con.install_extension("spatial")
con.load_extension("spatial")
con.sql("CREATE TABLE data_slice_male_long_lat AS SELECT * FROM data_slice_male_long_lat")
con.sql("DESCRIBE data_slice_male_long_lat")
# Out:
# ┌───────────────────────────────────────┬─────────────┬─────────┬─────────┬─────────┬─────────┐
# │              column_name              │ column_type │  null   │   key   │ default │  extra  │
# │                varchar                │   varchar   │ varchar │ varchar │ varchar │ varchar │
# ├───────────────────────────────────────┼─────────────┼─────────┼─────────┼─────────┼─────────┤
# │ latitude                              │ DOUBLE      │ YES     │ NULL    │ NULL    │ NULL    │
# │ longitude                             │ DOUBLE      │ YES     │ NULL    │ NULL    │ NULL    │
# │ male_population_density               │ FLOAT       │ YES     │ NULL    │ NULL    │ NULL    │
# │ male_population_density_ages_0_to_4   │ FLOAT       │ YES     │ NULL    │ NULL    │ NULL    │
# │ male_population_density_ages_5_to_9   │ FLOAT       │ YES     │ NULL    │ NULL    │ NULL    │
# │ male_population_density_ages_10_to_14 │ FLOAT       │ YES     │ NULL    │ NULL    │ NULL    │
# │ male_population_density_ages_15_to_19 │ FLOAT       │ YES     │ NULL    │ NULL    │ NULL    │
# │ male_population_density_ages_20_to_24 │ FLOAT       │ YES     │ NULL    │ NULL    │ NULL    │
# │ male_population_density_ages_25_to_29 │ FLOAT       │ YES     │ NULL    │ NULL    │ NULL    │
# │ male_population_density_ages_30_to_34 │ FLOAT       │ YES     │ NULL    │ NULL    │ NULL    │
# │            ·                          │   ·         │  ·      │  ·      │  ·      │  ·      │
# │            ·                          │   ·         │  ·      │  ·      │  ·      │  ·      │
# │            ·                          │   ·         │  ·      │  ·      │  ·      │  ·      │
# │ national_identifier_grid              │ FLOAT       │ YES     │ NULL    │ NULL    │ NULL    │
# │ data_code                             │ FLOAT       │ YES     │ NULL    │ NULL    │ NULL    │
# │ input_data_year                       │ FLOAT       │ YES     │ NULL    │ NULL    │ NULL    │
# │ input_data_level                      │ FLOAT       │ YES     │ NULL    │ NULL    │ NULL    │
# │ input_sex_data_level                  │ FLOAT       │ YES     │ NULL    │ NULL    │ NULL    │
# │ input_age_data_level                  │ FLOAT       │ YES     │ NULL    │ NULL    │ NULL    │
# │ growth_rate_start_year                │ FLOAT       │ YES     │ NULL    │ NULL    │ NULL    │
# │ growth_rate_end_year                  │ FLOAT       │ YES     │ NULL    │ NULL    │ NULL    │
# │ growth_rate_administrative_level      │ FLOAT       │ YES     │ NULL    │ NULL    │ NULL    │
# │ year_of_most_recent_census            │ FLOAT       │ YES     │ NULL    │ NULL    │ NULL    │
# ├───────────────────────────────────────┴─────────────┴─────────┴─────────┴─────────┴─────────┤
# │ 32 rows (20 shown)                                                                6 columns │
# └─────────────────────────────────────────────────────────────────────────────────────────────┘

# %% [markdown]
# Transform the longitude and latitude field into a geometry type

# %%
sql_query = """
SELECT latitude, longitude, ST_Point(longitude, latitude) AS geom
FROM data_slice_male_long_lat
"""
con.sql(sql_query)

# %%
# Add point geometry 
# Taken from https://motherduck.com/blog/getting-started-gis-duckdb/
con.sql("ALTER TABLE data_slice_male_long_lat ADD COLUMN geom GEOMETRY")
con.sql("UPDATE data_slice_male_long_lat SET geom = ST_Point(longitude, latitude)")
con.sql("DESCRIBE data_slice_male_long_lat")
# Out:
# ┌───────────────────────────────────────┬─────────────┬─────────┬─────────┬─────────┬─────────┐
# │              column_name              │ column_type │  null   │   key   │ default │  extra  │
# │                varchar                │   varchar   │ varchar │ varchar │ varchar │ varchar │
# ├───────────────────────────────────────┼─────────────┼─────────┼─────────┼─────────┼─────────┤
# │ latitude                              │ DOUBLE      │ YES     │ NULL    │ NULL    │ NULL    │
# │ longitude                             │ DOUBLE      │ YES     │ NULL    │ NULL    │ NULL    │
# │ male_population_density               │ FLOAT       │ YES     │ NULL    │ NULL    │ NULL    │
# │ male_population_density_ages_0_to_4   │ FLOAT       │ YES     │ NULL    │ NULL    │ NULL    │
# │ male_population_density_ages_5_to_9   │ FLOAT       │ YES     │ NULL    │ NULL    │ NULL    │
# │ male_population_density_ages_10_to_14 │ FLOAT       │ YES     │ NULL    │ NULL    │ NULL    │
# │ male_population_density_ages_15_to_19 │ FLOAT       │ YES     │ NULL    │ NULL    │ NULL    │
# │ male_population_density_ages_20_to_24 │ FLOAT       │ YES     │ NULL    │ NULL    │ NULL    │
# │ male_population_density_ages_25_to_29 │ FLOAT       │ YES     │ NULL    │ NULL    │ NULL    │
# │ male_population_density_ages_30_to_34 │ FLOAT       │ YES     │ NULL    │ NULL    │ NULL    │
# │     ·                                 │   ·         │  ·      │  ·      │  ·      │  ·      │
# │     ·                                 │   ·         │  ·      │  ·      │  ·      │  ·      │
# │     ·                                 │   ·         │  ·      │  ·      │  ·      │  ·      │
# │ data_code                             │ FLOAT       │ YES     │ NULL    │ NULL    │ NULL    │
# │ input_data_year                       │ FLOAT       │ YES     │ NULL    │ NULL    │ NULL    │
# │ input_data_level                      │ FLOAT       │ YES     │ NULL    │ NULL    │ NULL    │
# │ input_sex_data_level                  │ FLOAT       │ YES     │ NULL    │ NULL    │ NULL    │
# │ input_age_data_level                  │ FLOAT       │ YES     │ NULL    │ NULL    │ NULL    │
# │ growth_rate_start_year                │ FLOAT       │ YES     │ NULL    │ NULL    │ NULL    │
# │ growth_rate_end_year                  │ FLOAT       │ YES     │ NULL    │ NULL    │ NULL    │
# │ growth_rate_administrative_level      │ FLOAT       │ YES     │ NULL    │ NULL    │ NULL    │
# │ year_of_most_recent_census            │ FLOAT       │ YES     │ NULL    │ NULL    │ NULL    │
# │ geom                                  │ GEOMETRY    │ YES     │ NULL    │ NULL    │ NULL    │
# ├───────────────────────────────────────┴─────────────┴─────────┴─────────┴─────────┴─────────┤
# │ 33 rows (20 shown)                                                                6 columns │
# └─────────────────────────────────────────────────────────────────────────────────────────────┘

# %%
# Do we need to generate a quadkey for every level of zoom? Can we just use the index somehow?
sql_query = """
SELECT geom, 
    ST_QuadKey(geom, 1) as quadkey_z1,
    ST_QuadKey(geom, 2) as quadkey_z2,
    ST_QuadKey(geom, 3) as quadkey_z3,
    ST_QuadKey(geom, 4) as quadkey_z4,
    ST_QuadKey(geom, 5) as quadkey_z5,
    ST_QuadKey(geom, 6) as quadkey_z6,
    ST_QuadKey(geom, 7) as quadkey_z7,
    ST_QuadKey(geom, 8) as quadkey_z8,
    ST_QuadKey(geom, 9) as quadkey_z9,
    ST_QuadKey(geom, 10) as quadkey_z10,
    ST_QuadKey(geom, 11) as quadkey_z11,
    ST_QuadKey(geom, 12) as quadkey_z12,
    ST_QuadKey(geom, 13) as quadkey_z13,
    ST_QuadKey(geom, 14) as quadkey_z14
FROM data_slice_male_long_lat
"""
con.sql(sql_query)
# Out:
# ┌──────────────────────────────────────────────┬────────────┬────────────┬────────────┬────────────┬────────────┬────────────┬────────────┬────────────┬────────────�
columns │
# └───────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┘

# %%
#-- Create an R-tree index on the geometry column
con.sql("CREATE INDEX idx_data_slice_male_long_lat ON data_slice_male_long_lat USING RTREE (geom) WITH (max_node_capacity = 4)")
# Out:
# ---------------------------------------------------------------------------
# CatalogException                          Traceback (most recent call last)
# Cell In[29], line 2
#       1 #-- Create an R-tree index on the geometry column
# ----> 2 con.sql("CREATE INDEX idx_data_slice_male_long_lat ON data_slice_male_long_lat USING RTREE (geom) WITH (max_node_capacity = 4)")
#       4 con.sql("SELECT * FROM rtree_index_dump('idx_data_slice_male_long_lat')")
#
# CatalogException: Catalog Error: Index with name "idx_data_slice_male_long_lat" already exists

# %%
con.sql("SELECT * FROM rtree_index_dump('idx_data_slice_male_long_lat')")
# Out:
# ┌───────┬──────────────────────────────────────────────────────────────────────────────────┬────────┐
# │ level │                                      bounds                                      │ row_id │
# │ int32 │                                     box_2df                                      │ int64  │
# ├───────┼──────────────────────────────────────────────────────────────────────────────────┼────────┤
# │     0 │ {'min_x': 6.020833, 'min_y': -84.97917, 'max_x': 6.979167, 'max_y': 30.3125}     │   NULL │
# │     1 │ {'min_x': 6.020833, 'min_y': -84.97917, 'max_x': 6.979167, 'max_y': -55.6875}    │   NULL │
# │     2 │ {'min_x': 6.020833, 'min_y': -84.97917, 'max_x': 6.979167, 'max_y': -77.02083}   │   NULL │
# │     3 │ {'min_x': 6.020833, 'min_y': -84.97917, 'max_x': 6.979167, 'max_y': -82.354164}  │   NULL │
# │     4 │ {'min_x': 6.4375, 'min_y': -84.97917, 'max_x': 6.8125, 'max_y': -83.6875}        │   NULL │
# │     5 │ {'min_x': 6.4375, 'min_y': -84.97917, 'max_x': 6.5208335, 'max_y': -83.6875}     │   NULL │
# │     6 │ {'min_x': 6.4791665, 'min_y': -84.97917, 'max_x': 6.479167, 'max_y': -84.354164} │   NULL │
# │     7 │ {'min_x': 6.4791665, 'min_y': -84.97917, 'max_x': 6.479167, 'max_y': -84.854164} │   NULL │
# │     8 │ {'min_x': 6.4791665, 'min_y': -84.97917, 'max_x': 6.479167, 'max_y': -84.979164} │     11 │
# │     8 │ {'min_x': 6.4791665, 'min_y': -84.9375, 'max_x': 6.479167, 'max_y': -84.9375}    │     35 │
# │     · │                                       ·                                          │      · │
# │     · │                                       ·                                          │      · │
# │     · │                                       ·                                          │      · │
# │     8 │ {'min_x': 6.3541665, 'min_y': -72.97917, 'max_x': 6.354167, 'max_y': -72.979164} │   6920 │
# │     8 │ {'min_x': 6.3541665, 'min_y': -72.9375, 'max_x': 6.354167, 'max_y': -72.9375}    │   6944 │
# │     8 │ {'min_x': 6.3541665, 'min_y': -72.895836, 'max_x': 6.354167, 'max_y': -72.89583} │   6968 │
# │     8 │ {'min_x': 6.3541665, 'min_y': -72.85417, 'max_x': 6.354167, 'max_y': -72.854164} │   6992 │
# │     7 │ {'min_x': 6.3541665, 'min_y': -72.8125, 'max_x': 6.354167, 'max_y': -72.6875}    │   NULL │
# │     8 │ {'min_x': 6.3541665, 'min_y': -72.8125, 'max_x': 6.354167, 'max_y': -72.8125}    │   7016 │
# │     8 │ {'min_x': 6.3541665, 'min_y': -72.770836, 'max_x': 6.354167, 'max_y': -72.77083} │   7040 │
# │     8 │ {'min_x': 6.3541665, 'min_y': -72.72917, 'max_x': 6.354167, 'max_y': -72.729164} │   7064 │
# │     8 │ {'min_x': 6.3541665, 'min_y': -72.6875, 'max_x': 6.354167, 'max_y': -72.6875}    │   7088 │
# │     7 │ {'min_x': 6.3541665, 'min_y': -72.645836, 'max_x': 6.354167, 'max_y': -72.52083} │   NULL │
# ├───────┴──────────────────────────────────────────────────────────────────────────────────┴────────┤
# │ ? rows (>9999 rows, 20 shown)                                                           3 columns │
# └───────────────────────────────────────────────────────────────────────────────────────────────────┘

# %%
# Taken from https://duckdb.org/docs/extensions/spatial/r-tree_indexes
sql_query = """
SELECT 
  level, 
  bounds::GEOMETRY AS geom, 
  CASE WHEN row_id IS NULL THEN st_area(geom) ELSE NULL END AS area, 
  row_id, 
  CASE WHEN row_id IS NULL THEN 'branch' ELSE 'leaf' END AS kind 
FROM rtree_index_dump('idx_data_slice_male_long_lat') 
ORDER BY area DESC;
"""

con.sql(sql_query)
# Out:
# ┌───────┬─────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┬───────────────────────┬────────┬─────────┐
# │ level │                                                                                                    geom                                                                                                     │         area          │ row_id │  kind   │
# │ int32 │                                                                                                  geometry                                                                                                   │        double         │ int64  │ varchar │
# ├───────┼─────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┼───────────────────────┼────────┼─────────┤
# │     0 │ POLYGON ((6.020833015441894 -84.97917175292969, 6.020833015441894 30.3125, 6.979166984558106 30.3125, 6.979166984558106 -84.97917175292969, 6.020833015441894 -84.97917175292969))                          │    110.48792539702845 │   NULL │ branch  │
# │     0 │ POLYGON ((6.020833015441894 27.6875, 6.020833015441894 84.97917175292969, 6.979166984558106 84.97917175292969, 6.979166984558106 27.6875, 6.020833015441894 27.6875))                                       │    54.904555188288214 │   NULL │ branch  │
# │     1 │ POLYGON ((6.020833015441894 -58.3125, 6.020833015441894 -27.020832061767578, 6.979166984558106 -27.020832061767578, 6.979166984558106 -58.3125, 6.020833015441894 -58.3125))                                │    29.987868335512758 │   NULL │ branch  │
# │     1 │ POLYGON ((6.020833015441894 -29.64583396911621, 6.020833015441894 0.979166686534882, 6.979166984558106 0.979166686534882, 6.979166984558106 -29.64583396911621, 6.020833015441894 -29.64583396911621))      │    29.348978432516674 │   NULL │ branch  │
# │     1 │ POLYGON ((6.020833015441894 -0.3125, 6.020833015441894 30.3125, 6.979166984558106 30.3125, 6.979166984558106 -0.3125, 6.020833015441894 -0.3125))                                                           │     29.34897780418396 │   NULL │ branch  │
# │     1 │ POLYGON ((6.020833015441894 27.6875, 6.020833015441894 58.3125, 6.979166984558106 58.3125, 6.979166984558106 27.6875, 6.020833015441894 27.6875))                                                           │     29.34897780418396 │   NULL │ branch  │
# │     1 │ POLYGON ((6.020833015441894 -84.97917175292969, 6.020833015441894 -55.6875, 6.979166984558106 -55.6875, 6.979166984558106 -84.97917175292969, 6.020833015441894 -84.97917175292969))                        │    28.071204053034307 │   NULL │ branch  │
# │     1 │ POLYGON ((6.020833015441894 56.354164123535156, 6.020833015441894 84.97917175292969, 6.979166984558106 84.97917175292969, 6.979166984558106 56.354164123535156, 6.020833015441894 56.354164123535156))      │     27.43231717745948 │   NULL │ branch  │
# │     2 │ POLYGON ((6.020833015441894 -58.3125, 6.020833015441894 -48.354164123535156, 6.979166984558106 -48.354164123535156, 6.979166984558106 -58.3125, 6.020833015441894 -58.3125))                                │     9.543411546284915 │   NULL │ branch  │
